# %% [markdown]
# ## Installing Dependencies & utilize libraries neccessary

# %%
import json
import requests
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import os
from datetime import datetime
import re
import uuid
from urllib.parse import quote
import urllib.parse
import time
import logging
from concurrent.futures import ThreadPoolExecutor
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
import logging

# %% [markdown]
# Task 1 - Loading FHIR data from disk storage/source system

# %%
# Define the folder path for FHIR JSON files
folder_path = "/home/omarattia/Take-Home Assesment/patients_fhir_100"

# Load all JSON files from the folder
all_entries = []

# %% [markdown]
# Task 2 - Iterate and loop over all JSON files in the folder. Then showcase how many entries were made. Pre-defining the LOG file.

# %%
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r') as file:
            data = json.load(file)
            if 'entry' in data:  # Ensure 'entry' key exists
                all_entries.extend(data['entry'])

print(f"Loaded {len(all_entries)} entries.")

log_file_path = "/home/omarattia/Take-Home Assesment/FHIR_DWH_logs/At-Home_Assesment_ETL.log"

# Ensure the directory exists
os.makedirs(os.path.dirname(log_file_path), exist_ok=True)

logging.basicConfig(
    level=logging.DEBUG,  # Set the logging level to capture all log levels
    format='%(asctime)s - %(levelname)s - %(message)s',  # Format with timestamps and levels
    handlers=[
        logging.FileHandler(log_file_path),  # Write logs to the file
        logging.StreamHandler()  # Also output logs to the console
    ])


logging.info(f"DATA EXTRACTION 1: Loaded {len(all_entries)} entries.")
# Out:
# 2024-11-16 20:24:14,606 - INFO - DATA EXTRACTION 1: Loaded 230394 entries.
# Loaded 230394 entries.

# %% [markdown]
# Task 3 (Patient Information Dimension) - Parsing neccessary data from existing JSON files, based on the business requirements and KPIs. Chronolgically transforming data into user-friendly Dataframes.

# %%
# Helper function to remove numbers
def remove_numbers(name):
    return ''.join([i for i in name if not i.isdigit()])

def calculate_age(birth_date):
    if birth_date == "Unknown":
        return "Unknown"
    birth_year = datetime.strptime(birth_date, "%Y-%m-%d").year
    current_year = datetime.now().year
    return current_year - birth_year

# Extract patient information from all entries
patients = []
logging.info("DATA EXTRACTION 2.1: Starting patient data extraction.")
for entry in all_entries:
    resource = entry.get("resource", {})
    
    if resource.get("resourceType") == "Patient":
        name_data = resource.get("name", [{}])[0]
        address_data = resource.get("address", [{}])[0]
        contact_data = resource.get("telecom", [{}])
        identifier_data = resource.get("identifier", [])
        
        # Process first, middle, and last name
        first_name = " ".join([remove_numbers(name) for name in name_data.get("given", ["Unknown"])])
        last_name = remove_numbers(name_data.get("family", "Unknown"))
        middle_name = " ".join([remove_numbers(name) for name in name_data.get("given", [])[1:]])  # Middle name is anything after the first given name
        
        # If middle name exists, include it
        full_name = first_name
        if middle_name:
            full_name = f"{first_name} {middle_name}"

        # Extract the identifiers
        ssn = next((i.get("value") for i in identifier_data if i.get("type", {}).get("coding", [{}])[0].get("code") == "SS"), "Unknown")
        mrn = next((i.get("value") for i in identifier_data if i.get("type", {}).get("coding", [{}])[0].get("code") == "MR"), "Unknown")
        dl_number = next((i.get("value") for i in identifier_data if i.get("type", {}).get("coding", [{}])[0].get("code") == "DL"), "Unknown")
        passport = next((i.get("value") for i in identifier_data if i.get("type", {}).get("coding", [{}])[0].get("code") == "PPN"), "Unknown")
        
        # Process phone number (MSISDN)
        msisdn = next((c.get("value") for c in contact_data if c.get("system") == "phone"), "Unknown")

        patients.append({
            "PATIENT_ID": resource.get("id", "Unknown"),
            "FIRST_NAME": first_name,
            "MIDDLE_NAME": middle_name if middle_name else "Unknown",
            "LAST_NAME": last_name,
            "SSN": ssn,
            "MR_NUMBER": mrn,
            "DL_NUMBER": dl_number,  # Added Driver's License Number
            "PASSPORT_NUMBER": passport,  # Added Passport Number
            "GENDER": resource.get("gender", "Unknown"),
            "BIRTH_DATE": resource.get("birthDate", "Unknown"),
            "AGE": calculate_age(resource.get("birthDate")),
            "PATIENT_ADDRESS": " ".join(address_data.get("line", [])),
            "CITY": address_data.get("city", "Unknown"),
            "POSTAL_CODE": address_data.get("postalCode", "Unknown"),
            "COUNTRY": address_data.get("country", "Unknown"),
            "MSISDN": msisdn,
            "MARITAL_STATUS": resource.get("maritalStatus", {}).get("text", "Unknown")
        })

logging.info(f"DATA EXTRACTION 2.2: Extracted data for {len(patients)} patients.")

# Create the DataFrame from the patients list
patients_information_df = pd.DataFrame(patients)

logging.info(f"DATA TRANSFORMATION: Encounter DataFrame created with {patients_information_df.shape[0]} records.")

# Save the DataFrame to a CSV file
csv_file_path = "patient_infromation_dimension.csv"  # Specify your desired file path
patients_information_df.to_csv(csv_file_path, index=False)

# Show confirmation message
logging.info(f"DATA LOADING: Encounter event data has been saved to {csv_file_path}.")
print(f"Encounter event data has been saved to {csv_file_path}")
# Out:
# 2024-11-16 20:24:14,659 - INFO - DATA EXTRACTION 2.1: Starting patient data extraction.
# 2024-11-16 20:24:14,840 - INFO - DATA EXTRACTION 2.2: Extracted data for 100 patients.
# 2024-11-16 20:24:14,844 - INFO - DATA TRANSFORMATION: Encounter DataFrame created with 100 records.
# 2024-11-16 20:24:14,900 - INFO - DATA LOADING: Encounter event data has been saved to patient_infromation_dimension.csv.
# Encounter event data has been saved to patient_infromation_dimension.csv

# %% [markdown]
# Task 4 (Encounter Events Dimension) - Parsing neccessary data from existing JSON files, based on the business requirements and KPIs. Chronolgically transforming data into user-friendly Dataframes.

# %%
# Extract encounter information from all entries and transform it into the desired event format
encounter_events = []
logging.info("DATA EXTRACTION 3.1: Starting encounter data extraction.")
for entry in all_entries:
    resource = entry["resource"]
    resource_type = resource["resourceType"]
    
    # Process only "Encounter" type resources
    if resource_type == "Encounter":
        event_id = resource["id"]

        # Extract start and end date for the event, defaulting to "Unknown" if not found
        start_date = resource.get("period", {}).get("start", "Unknown")
        end_date = resource.get("period", {}).get("end", "Unknown")

        # If no period info, look for other relevant date info (like effective date, recorded date)
        if start_date == "Unknown" and "effectiveDateTime" in resource:
            start_date = resource["effectiveDateTime"]
        if end_date == "Unknown" and "issued" in resource:
            end_date = resource["issued"]

        # Related events (if available), referencing Encounter, Condition, etc.
        related_events = resource.get("subject", {}).get("reference", "Unknown")

        # Remove the "urn:uuid:" prefix from the Patient ID (i.e., extract only the UUID)
        patient_id = related_events.replace("urn:uuid:", "") if "urn:uuid:" in related_events else related_events

        # Encounter specific fields
        encounter_status = resource.get("status", "Unknown").title()
        encounter_type = resource.get("type", [{}])[0].get("text", "Unknown").title()

        # Extract location
        location = resource.get("location", [{}])[0].get("location", {}).get("display", "Unknown").title()

        # Collect event data for Encounter
        event_data = {
            "EVENT_TYPE": resource_type.title(),
            "EVENT_ID": event_id,
            "START_DATETIME": start_date,
            "END_DATETIME": end_date,
            "PATIENT_ID": patient_id,  # Removed the urn:uuid: prefix
            "ENCOUNTER_STATUS": encounter_status,
            "ENCOUNTER_TYPE": encounter_type,
            "LOCATION": location
        }

        # Add the event data to the list
        encounter_events.append(event_data)

logging.info(f"DATA EXTRACTION 3.2: Extracted {len(encounter_events)} encounter events.")

# Create a DataFrame from the encounter event data
events_encounters_df = pd.DataFrame(encounter_events)

logging.info(f"DATA TRANSFORMATION: Encounter DataFrame created with {events_encounters_df.shape[0]} records.")

# Save the DataFrame to a CSV file
csv_file_path = "events_encounters.csv"  # Specify your desired file path
events_encounters_df.to_csv(csv_file_path, index=False)

# Show confirmation message
logging.info(f"DATA LOADING: Encounter event data has been saved to {csv_file_path}.")
print(f"Encounter event data has been saved to {csv_file_path}")
# Out:
# 2024-11-16 20:24:14,916 - INFO - DATA EXTRACTION 3.1: Starting encounter data extraction.
# 2024-11-16 20:24:15,121 - INFO - DATA EXTRACTION 3.2: Extracted 9868 encounter events.
# 2024-11-16 20:24:15,141 - INFO - DATA TRANSFORMATION: Encounter DataFrame created with 9868 records.
# 2024-11-16 20:24:15,217 - INFO - DATA LOADING: Encounter event data has been saved to events_encounters.csv.
# Encounter event data has been saved to events_encounters.csv

# %% [markdown]
# Task 5 (Dignosis Report Events Dimension) - Parsing neccessary data from existing JSON files, based on the business requirements and KPIs. Chronolgically transforming data into user-friendly Dataframes.

# %%
# Helper function to remove numbers from names and clean them up
def remove_numbers(name):
    return ''.join([i for i in name if not i.isdigit()]).strip().title()

# Extract diagnostic report information from all entries and transform it into the desired format
diagnostic_report_events = []
logging.info("DATA EXTRACTION 4.1: Starting diagnostic report data extraction.")

for entry in all_entries:
    resource = entry["resource"]
    resource_type = resource["resourceType"]
    
    # Process only "DiagnosticReport" type resources
    if resource_type == "DiagnosticReport":
        event_id = resource["id"]

        # Extract start and end date for the event, defaulting to "Unknown" if not found
        start_date = resource.get("effectiveDateTime", "Unknown")
        end_date = resource.get("issued", "Unknown")

        # Related events (if available), referencing DiagnosticReport, Condition, etc.
        related_events = resource.get("subject", {}).get("reference", "Unknown")

        # Remove the "urn:uuid:" prefix from the Patient ID (i.e., extract only the UUID)
        patient_id = related_events.replace("urn:uuid:", "") if "urn:uuid:" in related_events else related_events

        # DiagnosticReport specific fields
        status = resource.get("status", "Unknown").title()
        category = ", ".join([cat.get("coding", [{}])[0].get("display", "Unknown").title() for cat in resource.get("category", [])])

        # Extract practitioner/performer and remove numbers from their names
        performer_list = resource.get("performer", [])
        practitioner_performer = ", ".join([remove_numbers(pr.get("display", "Unknown")) for pr in performer_list])

        # Collect event data for DiagnosticReport
        event_data = {
            "EVENT_TYPE": resource_type.title(),
            "EVENT_ID": event_id,
            "START_DATETIME": start_date,
            "END_DATETIME": end_date,
            "PATIENT_ID": patient_id,  # Removed the urn:uuid: prefix
            "STATUS": status,
            "CATEGORY": category,
            "PRACTITIONER_PERFORMER": practitioner_performer
        }

        # Add the event data to the list
        diagnostic_report_events.append(event_data)

logging.info(f"DATA EXTRACTION 4.2: Extracted {len(diagnostic_report_events)} diagnostic report events.")

# Create a DataFrame from the diagnostic report event data
events_diagnostic_report_df = pd.DataFrame(diagnostic_report_events)

logging.info(f"DATA TRANSFORMATION: Diagnostic report DataFrame created with {events_diagnostic_report_df.shape[0]} records.")

# Specifically fill missing values in "PRACTITIONER_PERFORMER" and "CATEGORY" columns with "Unknown"
events_diagnostic_report_df['PRACTITIONER_PERFORMER'].replace("", "Unknown", inplace=True)
events_diagnostic_report_df['CATEGORY'].replace("", "Unknown", inplace=True)
events_diagnostic_report_df.fillna({"PRACTITIONER_PERFORMER": "Unknown", "CATEGORY": "Unknown"}, inplace=True)

# Save the DataFrame to a CSV file
csv_file_path = "events_diagnostic_report.csv"  # Specify your desired file path
events_diagnostic_report_df.to_csv(csv_file_path, index=False)

# Show confirmation message
logging.info(f"DATA LOADING: Diagnostic report event data has been saved to {csv_file_path}.")
print(f"DiagnosticReport event data has been saved to {csv_file_path}")
# Out:
# 2024-11-16 20:24:15,235 - INFO - DATA EXTRACTION 4.1: Starting diagnostic report data extraction.
# 2024-11-16 20:24:15,574 - INFO - DATA EXTRACTION 4.2: Extracted 20149 diagnostic report events.
# 2024-11-16 20:24:15,606 - INFO - DATA TRANSFORMATION: Diagnostic report DataFrame created with 20149 records.
# 2024-11-16 20:24:15,796 - INFO - DATA LOADING: Diagnostic report event data has been saved to events_diagnostic_report.csv.
# DiagnosticReport event data has been saved to events_diagnostic_report.csv

# %% [markdown]
# Task 6 (Condition Events Dimension) - Parsing neccessary data from existing JSON files, based on the business requirements and KPIs. Chronolgically transforming data into user-friendly Dataframes.

# %%
# Helper function to remove the "urn:uuid:" prefix
def remove_prefix(value):
    return value.replace("urn:uuid:", "") if "urn:uuid:" in value else value

# Map condition status to boolean values
def map_condition_status(status):
    status_lower = status.lower()
    if status_lower == "active":
        return 0  # Active is 0
    elif status_lower == "resolved":
        return 1  # Resolved is 1
    return None  # For unknown statuses

# Extract condition information from all entries and transform it into the desired format
condition_events = []
logging.info("DATA EXTRACTION 5.1: Starting condition data extraction.")

for entry in all_entries:
    resource = entry["resource"]
    resource_type = resource["resourceType"]
    
    # Process only "Condition" type resources
    if resource_type == "Condition":
        event_id = resource["id"]

        # Related events (Patient ID), remove "urn:uuid:" prefix
        related_events = resource.get("subject", {}).get("reference", "Unknown")
        patient_id = remove_prefix(related_events)

        # Condition specific fields
        condition_status = resource.get("clinicalStatus", {}).get("coding", [{}])[0].get("code", "Unknown")
        condition_boolean = map_condition_status(condition_status)
        medical_diagnosis = resource.get("code", {}).get("text", "Unknown")
        condition_onset = resource.get("onsetDateTime", "Unknown")
        condition_record_date = resource.get("recordedDate", "Unknown")

        # Collect event data for Condition
        event_data = {
            "EVENT_TYPE": resource_type.title(),
            "EVENT_ID": event_id,
            "PATIENT_ID": patient_id,  # Removed the urn:uuid: prefix
            "CONDITION": condition_boolean,  # Boolean for condition status
            "MEDICAL_DIAGNOSIS": medical_diagnosis,
            "CONDITION_ONSET": condition_onset,
            "CONDITION_RECORD_DATE": condition_record_date
        }

        # Add the event data to the list
        condition_events.append(event_data)

logging.info(f"DATA EXTRACTION 5.2: Extracted {len(condition_events)} condition events.")

# Create a DataFrame from the condition event data
events_conditions_df = pd.DataFrame(condition_events)

logging.info(f"DATA TRANSFORMATION: Condition DataFrame created with {events_conditions_df.shape[0]} records.")

# Save the DataFrame to a CSV file
csv_file_path = "events_conditions.csv"  # Specify your desired file path
events_conditions_df.to_csv(csv_file_path, index=False)

# Show confirmation message
logging.info(f"DATA LOADING: Condition event data has been saved to {csv_file_path}.")
print(f"Condition event data has been saved to {csv_file_path}")
# Out:
# 2024-11-16 20:24:15,815 - INFO - DATA EXTRACTION 5.1: Starting condition data extraction.
# 2024-11-16 20:24:15,990 - INFO - DATA EXTRACTION 5.2: Extracted 4892 condition events.
# 2024-11-16 20:24:16,004 - INFO - DATA TRANSFORMATION: Condition DataFrame created with 4892 records.
# 2024-11-16 20:24:16,050 - INFO - DATA LOADING: Condition event data has been saved to events_conditions.csv.
# Condition event data has been saved to events_conditions.csv

# %% [markdown]
# Task 7 (Claims, EOBs, and Medicine Requests Dimensions) - Parsing neccessary data from existing JSON files, based on the business requirements and KPIs. Chronolgically transforming data into user-friendly Dataframes.

# %%
# Helper function to remove "urn:uuid:" prefix
def remove_prefix(value):
    return value.replace("urn:uuid:", "") if "urn:uuid:" in value else value

# Helper function to clean up prescriber names by removing numbers and symbols
def clean_prescriber_name(name):
    clean_name = re.sub(r'[^a-zA-Z\s]', '', name).strip()
    return clean_name.title()

# Initialize lists to store dimension data
medication_data = []
claim_data = []
eob_data = []

# Log the start of the extraction process
logging.info("DATA EXTRACTION 6.1: Starting data extraction from all entries.")

# Iterate through all entries in the JSON data
for entry in all_entries:
    resource = entry["resource"]
    resource_type = resource["resourceType"]

    # Process MedicationRequest
    if resource_type == "MedicationRequest":
        medication_name = resource.get("medicationCodeableConcept", {}).get("text", "No Medication Prescribed")  # Replace Unknown
        dosage = resource.get("dosageInstruction", [{}])[0].get("doseAndRate", [{}])[0].get("doseQuantity", {}).get("value", "Unknown")
        frequency = resource.get("dosageInstruction", [{}])[0].get("timing", {}).get("repeat", {}).get("frequency", "Unknown")
        period_unit = resource.get("dosageInstruction", [{}])[0].get("timing", {}).get("repeat", {}).get("periodUnit", "Unknown")
        patient_id = remove_prefix(resource.get("subject", {}).get("reference", "Unknown"))
        prescriber = clean_prescriber_name(resource.get("requester", {}).get("display", "Unknown"))  # Clean prescriber name
        reason = resource.get("reasonReference", [{}])[0].get("display", "Unknown")

        medication_data.append({
            "MEDICATION_NAME": medication_name,
            "DOSAGE": f"{dosage} {frequency} per {period_unit}" if dosage != "Unknown" else "Unknown",
            "PATIENT_ID": patient_id,
            "PRESCRIBER": prescriber,
            "REASON": reason
        })

    # Process Claim
    elif resource_type == "Claim":
        claim_id = resource["id"]
        status = resource.get("status", "Unknown").title()
        billable_period_start = resource.get("billablePeriod", {}).get("start", "Unknown")
        billable_period_end = resource.get("billablePeriod", {}).get("end", "Unknown")
        cost = resource.get("total", {}).get("value", "Unknown")
        currency = resource.get("total", {}).get("currency", "Unknown")
        insurance = resource.get("insurance", [{}])[0].get("coverage", {}).get("display", "Unknown")
        patient_id = remove_prefix(resource.get("patient", {}).get("reference", "Unknown"))
        prescription_id = remove_prefix(resource.get("prescription", {}).get("reference", "Unknown"))

        claim_data.append({
            "CLAIM_ID": claim_id,
            "STATUS": status,
            "BILLABLE_PERIOD_START": billable_period_start,
            "BILLABLE_PERIOD_END": billable_period_end,
            "COST": cost,
            "CURRENCY": currency,
            "INSURANCE": insurance,
            "PATIENT_ID": patient_id,
            "PRESCRIPTION_ID": prescription_id
        })

    # Process ExplanationOfBenefit
    elif resource_type == "ExplanationOfBenefit":
        eob_id = resource["id"]
        status = resource.get("status", "Unknown").title()
        billable_period_start = resource.get("billablePeriod", {}).get("start", "Unknown")
        billable_period_end = resource.get("billablePeriod", {}).get("end", "Unknown")
        total_amount = resource.get("total", [{}])[0].get("amount", {}).get("value", "Unknown")
        currency = resource.get("total", [{}])[0].get("amount", {}).get("currency", "Unknown")
        insurer = resource.get("insurer", {}).get("display", "Unknown")
        facility = resource.get("facility", {}).get("display", "Unknown")
        patient_id = remove_prefix(resource.get("patient", {}).get("reference", "Unknown"))

        eob_data.append({
            "EOB_ID": eob_id,
            "STATUS": status,
            "BILLABLE_PERIOD_START": billable_period_start,
            "BILLABLE_PERIOD_END": billable_period_end,
            "TOTAL_AMOUNT": total_amount,
            "CURRENCY": currency,
            "INSURER": insurer,
            "FACILITY": facility,
            "PATIENT_ID": patient_id
        })

# Log the end of the extraction
logging.info(f"DATA EXTRACTION 6.2: Loaded {len(all_entries)} entries and extracted data.")

# Convert the lists to DataFrames
medication_prescibed_df = pd.DataFrame(medication_data)
claim_df = pd.DataFrame(claim_data)
eob_df = pd.DataFrame(eob_data)

# Log the creation of the DataFrames
logging.info("DATA TRANSFORMATION: DataFrames created for Medication, Claim, and ExplanationOfBenefit.")

# Add a unique ID column for medication names
medication_prescibed_df['MEDICATION_ID'] = medication_prescibed_df['MEDICATION_NAME'].apply(lambda x: hash(x))

# Log the creation of MEDICATION_ID
logging.info("DATA TRANSFORMATION 2: MEDICATION_ID added for each medication.")

# Save the DataFrames to CSV files
medication_prescibed_df.to_csv("medication_prescibed.csv", index=False)
claim_df.to_csv("claim_dimension.csv", index=False)
eob_df.to_csv("eob_dimension.csv", index=False)

# Log the completion of the data loading process
logging.info("DATA LOADING: Data has been saved to CSV files.")

# Confirmation messages
print("Medication dimension saved to 'medication_prescibed.csv'")
print("Claim dimension saved to 'claim_dimension.csv'")
print("ExplanationOfBenefit dimension saved to 'eob_dimension.csv'")

# Filter out rows with "No Medication Prescribed"
medication_df = medication_prescibed_df[medication_prescibed_df['MEDICATION_NAME'] != "No Medication Prescribed"]

# Remove duplicate medication names
medication_df = medication_df.drop_duplicates(subset=["MEDICATION_NAME"])

# Log after filtering duplicates
logging.info("DATA CLEANING: Removed rows with 'No Medication Prescribed' and duplicates.")
# Out:
# 2024-11-16 20:24:16,138 - INFO - DATA EXTRACTION 6.1: Starting data extraction from all entries.
# 2024-11-16 20:24:16,631 - INFO - DATA EXTRACTION 6.2: Loaded 230394 entries and extracted data.
# 2024-11-16 20:24:16,809 - INFO - DATA TRANSFORMATION: DataFrames created for Medication, Claim, and ExplanationOfBenefit.
# 2024-11-16 20:24:16,817 - INFO - DATA TRANSFORMATION 2: MEDICATION_ID added for each medication.
# 2024-11-16 20:24:17,194 - INFO - DATA LOADING: Data has been saved to CSV files.
# 2024-11-16 20:24:17,237 - INFO - DATA CLEANING: Removed rows with 'No Medication Prescribed' and duplicates.
# Medication dimension saved to 'medication_prescibed.csv'
# Claim dimension saved to 'claim_dimension.csv'
# ExplanationOfBenefit dimension saved to 'eob_dimension.csv'

# %% [markdown]
# Task 8 (Medicine Descriptive Dimension) - Parsing neccessary data from FDA Drug Label API and transforming the data.

# %%
# Helper function to remove "urn:uuid:" prefix
def remove_prefix(value):
    return value.replace("urn:uuid:", "") if "urn:uuid:" in value else value

# Helper function to clean up prescriber names by removing numbers and symbols
def clean_prescriber_name(name):
    clean_name = re.sub(r'[^a-zA-Z\s]', '', name).strip()
    return clean_name.title()

# Function to query the FDA Drug Label API using the EXTRACTED_MED_NAME
def query_fda_api(medication_name):
    base_url = "https://api.fda.gov/drug/label.json"
    params = {"search": f"openfda.brand_name:{medication_name}", "limit": 1}
    try:
        response = requests.get(base_url, params=params, timeout=10)
        if response.status_code == 200:
            results = response.json()
            if results.get("results"):
                fda_details = results["results"][0]
                return {
                    "BRAND_NAME": truncate_value(", ".join(fda_details.get("openfda", {}).get("brand_name", ["Unknown"]))),
                    "GENERIC_NAME": truncate_value(", ".join(fda_details.get("openfda", {}).get("generic_name", ["Unknown"]))),
                    "MANUFACTURER": truncate_value(", ".join(fda_details.get("openfda", {}).get("manufacturer_name", ["Unknown"]))),
                    "ACTIVE_INGREDIENT": truncate_value(", ".join(fda_details.get("active_ingredient", ["Unknown"]))),
                    "INDICATIONS_AND_USAGE": truncate_value(", ".join(fda_details.get("indications_and_usage", ["Unknown"]))),
                    "SUBSTANCE_NAME": truncate_value(", ".join(fda_details.get("openfda", {}).get("substance_name", ["Unknown"]))),
                    "PRODUCT_TYPE": truncate_value(", ".join(fda_details.get("openfda", {}).get("product_type", ["Unknown"]))),
                    "PURPOSE": truncate_value(", ".join(fda_details.get("purpose", ["Unknown"]))),
                    "ROUTE": truncate_value(", ".join(fda_details.get("route", ["Unknown"]))),
                    "DOSAGE_AND_ADMINISTRATION": truncate_value(", ".join(fda_details.get("dosage_and_administration", ["Unknown"]))),
                }
            return {"BRAND_NAME": "Not Available"}
        else:
            return {"BRAND_NAME": "API Error"}
    except Exception as e:
        logging.error(f"API Error for {medication_name}: {e}")
        return {"BRAND_NAME": "API Error"}

# Helper function to truncate text to 200 characters
def truncate_value(value):
    return value[:200]

# Function to extract the medication name (only the text) from the 'MEDICATION_NAME'
def extract_medication_name(medication_name):
    # Extract the text before any numbers or brackets
    match = re.match(r"([a-zA-Z\s]+)", medication_name)
    return match.group(0) if match else medication_name

# Function to process each medication name and query the FDA API
def process_medication(index_row, medication_df):
    index, row = index_row
    medication_name = row['EXTRACTED_MED_NAME']
    
    # Log the start of medication processing
    logging.info(f"DATA EXTRACTION 4: Processing medication '{medication_name}' (Index: {index}).")

    # Query the FDA API for the medication details using EXTRACTED_MED_NAME
    fda_details = query_fda_api(medication_name)
    
    # Add the new columns to the DataFrame (use .at to avoid copy warnings)
    for column, value in fda_details.items():
        medication_df.at[index, column] = value

    # Log the completion of processing for this medication
    logging.info(f"DATA EXTRACTION 4.1: Completed processing for medication '{medication_name}' (Index: {index}).")

# Assuming medication_prescibed_df is already populated with the data

# Log the start of EXTRACTED_MED_NAME extraction
logging.info("DATA EXTRACTION 3.1: Extracting EXTRACTED_MED_NAME from MEDICATION_NAME.")

# Add EXTRACTED_MED_NAME column by extracting only the text from MEDICATION_NAME
medication_prescibed_df['EXTRACTED_MED_NAME'] = medication_prescibed_df['MEDICATION_NAME'].apply(extract_medication_name)

# Log the completion of EXTRACTED_MED_NAME extraction
logging.info("DATA EXTRACTION 3.2: EXTRACTED_MED_NAME column added to the DataFrame.")

# Filter out rows with "No Medication Prescribed"
medication_df = medication_prescibed_df[medication_prescibed_df['MEDICATION_NAME'] != "No Medication Prescribed"]

# Remove duplicate medication names based on EXTRACTED_MED_NAME
medication_df = medication_df.drop_duplicates(subset=["EXTRACTED_MED_NAME"])

# Log after filtering and removing duplicates
logging.info("DATA CLEANING 1: Filtered out rows with 'No Medication Prescribed' and removed duplicates.")

# Set up parallel processing with ThreadPoolExecutor
with ThreadPoolExecutor(max_workers=5) as executor:
    # Log the start of parallel processing
    logging.info("DATA EXTRACTION 5: Starting parallel processing for medication data.")

    # Submit individual tasks for each medication row
    futures = [executor.submit(process_medication, index_row, medication_df) for index_row in medication_df.iterrows()]

    # Wait for all futures to complete
    for future in futures:
        future.result()

    # Log the completion of parallel processing
    logging.info("DATA EXTRACTION 6: Completed parallel processing for all medications.")

# Log the saving of the DataFrame to CSV
logging.info("DATA LOADING: Saving the final DataFrame with 'EXTRACTED_MED_NAME' to CSV.")

# Save the final DataFrame with the added 'EXTRACTED_MED_NAME' to CSV
medication_df.to_csv("medication_dimension.csv", index=False)

# Log the successful completion of the ETL process
logging.info("ETL Process Complete: Data processing and saving to CSV completed successfully.")

# Show confirmation message
print("Data processing complete.")
# Out:
# 2024-11-16 20:24:17,265 - INFO - DATA EXTRACTION 3.1: Extracting EXTRACTED_MED_NAME from MEDICATION_NAME.
# 2024-11-16 20:24:17,285 - INFO - DATA EXTRACTION 3.2: EXTRACTED_MED_NAME column added to the DataFrame.
# 2024-11-16 20:24:17,300 - INFO - DATA CLEANING 1: Filtered out rows with 'No Medication Prescribed' and removed duplicates.
# 2024-11-16 20:24:17,301 - INFO - DATA EXTRACTION 5: Starting parallel processing for medication data.
# 2024-11-16 20:24:17,303 - INFO - DATA EXTRACTION 4: Processing medication 'Clopidogrel ' (Index: 0).
# 2024-11-16 20:24:17,305 - INFO - DATA EXTRACTION 4: Processing medication 'Simvastatin ' (Index: 1).
# 2024-11-16 20:24:17,307 - INFO - DATA EXTRACTION 4: Processing medication '24 HR metoprolol succinate 100 MG Extended Release Oral Tablet' (Index: 2).
# 2024-11-16 20:24:17,308 - INFO - DATA EXTRACTION 4: Processing medication 'Nitroglycerin ' (Index: 3).
# 2024-11-16 20:24:17,310 - INFO - DATA EXTRACTION 4: Processing medication 'insulin isophane' (Index: 4).
# 2024-11-16 20:24:17,319 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:17,320 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:17,321 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:17,343 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:17,346 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:18,825 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ANitroglycerin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:18,985 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Ainsulin+isophane&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:18,986 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AClopidogrel+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:18,991 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Nitroglycerin ' (Index: 3).
# 2024-11-16 20:24:18,995 - INFO - DATA EXTRACTION 4: Processing medication 'Hydrochlorothiazide ' (Index: 5).
# 2024-11-16 20:24:18,997 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:19,031 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Clopidogrel ' (Index: 0).
# 2024-11-16 20:24:19,032 - INFO - DATA EXTRACTION 4: Processing medication 'Acetaminophen ' (Index: 6).
# 2024-11-16 20:24:19,034 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:19,059 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ASimvastatin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:19,073 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'insulin isophane' (Index: 4).
# 2024-11-16 20:24:19,075 - INFO - DATA EXTRACTION 4: Processing medication 'Galantamine ' (Index: 427).
# 2024-11-16 20:24:19,077 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:19,265 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Simvastatin ' (Index: 1).
# 2024-11-16 20:24:19,266 - INFO - DATA EXTRACTION 4: Processing medication 'amLODIPine ' (Index: 1054).
# 2024-11-16 20:24:19,268 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:19,383 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A24+HR+metoprolol+succinate+100+MG+Extended+Release+Oral+Tablet&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:19,385 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '24 HR metoprolol succinate 100 MG Extended Release Oral Tablet' (Index: 2).
# 2024-11-16 20:24:19,386 - INFO - DATA EXTRACTION 4: Processing medication 'Meperidine Hydrochloride ' (Index: 1080).
# 2024-11-16 20:24:19,388 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:19,958 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AHydrochlorothiazide+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:19,991 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AAcetaminophen+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:19,994 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Acetaminophen ' (Index: 6).
# 2024-11-16 20:24:19,998 - INFO - DATA EXTRACTION 4: Processing medication 'Naproxen sodium ' (Index: 1081).
# 2024-11-16 20:24:20,000 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:20,179 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Hydrochlorothiazide ' (Index: 5).
# 2024-11-16 20:24:20,180 - INFO - DATA EXTRACTION 4: Processing medication 'carbamazepine ' (Index: 1109).
# 2024-11-16 20:24:20,182 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:20,214 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AGalantamine+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:20,321 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Galantamine ' (Index: 427).
# 2024-11-16 20:24:20,323 - INFO - DATA EXTRACTION 4: Processing medication 'Diazepam ' (Index: 1184).
# 2024-11-16 20:24:20,325 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:20,421 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AamLODIPine+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:20,476 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'amLODIPine ' (Index: 1054).
# 2024-11-16 20:24:20,477 - INFO - DATA EXTRACTION 4: Processing medication 'Penicillin G ' (Index: 1286).
# 2024-11-16 20:24:20,480 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:20,511 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AMeperidine+Hydrochloride+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:20,514 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Meperidine Hydrochloride ' (Index: 1080).
# 2024-11-16 20:24:20,515 - INFO - DATA EXTRACTION 4: Processing medication 'Amoxicillin ' (Index: 1485).
# 2024-11-16 20:24:20,518 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:21,015 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ANaproxen+sodium+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:21,020 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Naproxen sodium ' (Index: 1081).
# 2024-11-16 20:24:21,021 - INFO - DATA EXTRACTION 4: Processing medication 'Jolivette ' (Index: 1518).
# 2024-11-16 20:24:21,023 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:21,266 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Acarbamazepine+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:21,319 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'carbamazepine ' (Index: 1109).
# 2024-11-16 20:24:21,321 - INFO - DATA EXTRACTION 4: Processing medication 'Natazia ' (Index: 1519).
# 2024-11-16 20:24:21,322 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:21,439 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ADiazepam+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:21,460 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Diazepam ' (Index: 1184).
# 2024-11-16 20:24:21,462 - INFO - DATA EXTRACTION 4: Processing medication 'Yaz ' (Index: 1525).
# 2024-11-16 20:24:21,463 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:21,534 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3APenicillin+G+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:21,537 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Penicillin G ' (Index: 1286).
# 2024-11-16 20:24:21,537 - INFO - DATA EXTRACTION 4: Processing medication 'Seasonique ' (Index: 1526).
# 2024-11-16 20:24:21,539 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:21,601 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AAmoxicillin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:21,607 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Amoxicillin ' (Index: 1485).
# 2024-11-16 20:24:21,609 - INFO - DATA EXTRACTION 4: Processing medication 'Errin ' (Index: 1527).
# 2024-11-16 20:24:21,613 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:22,064 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AJolivette+&limit=1 HTTP/11" 404 None
# 2024-11-16 20:24:22,066 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Jolivette ' (Index: 1518).
# 2024-11-16 20:24:22,067 - INFO - DATA EXTRACTION 4: Processing medication 'Ibuprofen ' (Index: 1556).
# 2024-11-16 20:24:22,069 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:22,483 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ASeasonique+&limit=1 HTTP/11" 404 None
# 2024-11-16 20:24:22,486 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Seasonique ' (Index: 1526).
# 2024-11-16 20:24:22,487 - INFO - DATA EXTRACTION 4: Processing medication '24 HR tacrolimus 1 MG Extended Release Oral Tablet' (Index: 2179).
# 2024-11-16 20:24:22,491 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:22,500 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ANatazia+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:22,505 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Natazia ' (Index: 1519).
# 2024-11-16 20:24:22,506 - INFO - DATA EXTRACTION 4: Processing medication 'ferrous sulfate ' (Index: 2195).
# 2024-11-16 20:24:22,508 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:22,632 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AYaz+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:22,640 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Yaz ' (Index: 1525).
# 2024-11-16 20:24:22,642 - INFO - DATA EXTRACTION 4: Processing medication 'lisinopril ' (Index: 2196).
# 2024-11-16 20:24:22,644 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:22,725 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AErrin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:22,767 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Errin ' (Index: 1527).
# 2024-11-16 20:24:22,768 - INFO - DATA EXTRACTION 4: Processing medication 'albuterol ' (Index: 2527).
# 2024-11-16 20:24:22,770 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:23,015 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AIbuprofen+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:23,018 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Ibuprofen ' (Index: 1556).
# 2024-11-16 20:24:23,019 - INFO - DATA EXTRACTION 4: Processing medication '60 ACTUAT Fluticasone propionate 0.25 MG/ACTUAT / salmeterol 0.05 MG/ACTUAT Dry Powder Inhaler' (Index: 2530).
# 2024-11-16 20:24:23,021 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:23,582 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Alisinopril+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:23,789 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'lisinopril ' (Index: 2196).
# 2024-11-16 20:24:23,790 - INFO - DATA EXTRACTION 4: Processing medication 'Alendronic acid ' (Index: 2595).
# 2024-11-16 20:24:23,792 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:23,836 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A24+HR+tacrolimus+1+MG+Extended+Release+Oral+Tablet&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:23,837 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '24 HR tacrolimus 1 MG Extended Release Oral Tablet' (Index: 2179).
# 2024-11-16 20:24:23,839 - INFO - DATA EXTRACTION 4: Processing medication 'Chlorpheniramine Maleate ' (Index: 2610).
# 2024-11-16 20:24:23,841 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:23,875 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Aferrous+sulfate+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:23,905 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Aalbuterol+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:23,918 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'albuterol ' (Index: 2527).
# 2024-11-16 20:24:23,919 - INFO - DATA EXTRACTION 4: Processing medication '120 ACTUAT fluticasone propionate 0.11 MG/ACTUAT Metered Dose Inhaler [Flovent]' (Index: 2611).
# 2024-11-16 20:24:23,920 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:24,004 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A60+ACTUAT+Fluticasone+propionate+0.25+MG%2FACTUAT+%2F+salmeterol+0.05+MG%2FACTUAT+Dry+Powder+Inhaler&limit=1 HTTP/11" 500 247
# 2024-11-16 20:24:24,006 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '60 ACTUAT Fluticasone propionate 0.25 MG/ACTUAT / salmeterol 0.05 MG/ACTUAT Dry Powder Inhaler' (Index: 2530).
# 2024-11-16 20:24:24,008 - INFO - DATA EXTRACTION 4: Processing medication '24 HR tacrolimus 5 MG Extended Release Oral Capsule' (Index: 2912).
# 2024-11-16 20:24:24,010 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:24,116 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'ferrous sulfate ' (Index: 2195).
# 2024-11-16 20:24:24,117 - INFO - DATA EXTRACTION 4: Processing medication 'Penicillin V Potassium ' (Index: 2960).
# 2024-11-16 20:24:24,119 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:24,900 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AChlorpheniramine+Maleate+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:24,902 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Chlorpheniramine Maleate ' (Index: 2610).
# 2024-11-16 20:24:24,903 - INFO - DATA EXTRACTION 4: Processing medication 'amoxicillin ' (Index: 2976).
# 2024-11-16 20:24:24,906 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:24,921 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AAlendronic+acid+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:24,923 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Alendronic acid ' (Index: 2595).
# 2024-11-16 20:24:24,924 - INFO - DATA EXTRACTION 4: Processing medication 'nitrofurantoin' (Index: 2977).
# 2024-11-16 20:24:24,926 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:24,952 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A120+ACTUAT+fluticasone+propionate+0.11+MG%2FACTUAT+Metered+Dose+Inhaler+%5BFlovent%5D&limit=1 HTTP/11" 500 258
# 2024-11-16 20:24:24,954 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '120 ACTUAT fluticasone propionate 0.11 MG/ACTUAT Metered Dose Inhaler [Flovent]' (Index: 2611).
# 2024-11-16 20:24:24,955 - INFO - DATA EXTRACTION 4: Processing medication 'nicotine ' (Index: 2988).
# 2024-11-16 20:24:24,957 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:25,243 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A24+HR+tacrolimus+5+MG+Extended+Release+Oral+Capsule&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:25,248 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '24 HR tacrolimus 5 MG Extended Release Oral Capsule' (Index: 2912).
# 2024-11-16 20:24:25,249 - INFO - DATA EXTRACTION 4: Processing medication 'Aspirin ' (Index: 3042).
# 2024-11-16 20:24:25,251 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:25,292 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3APenicillin+V+Potassium+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:25,532 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Penicillin V Potassium ' (Index: 2960).
# 2024-11-16 20:24:25,533 - INFO - DATA EXTRACTION 4: Processing medication 'Fexofenadine hydrochloride ' (Index: 3700).
# 2024-11-16 20:24:25,535 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:25,996 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Anitrofurantoin&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:26,000 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Anicotine+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:26,005 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'nicotine ' (Index: 2988).
# 2024-11-16 20:24:26,007 - INFO - DATA EXTRACTION 4: Processing medication 'NDA' (Index: 3701).
# 2024-11-16 20:24:26,009 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:26,023 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Aamoxicillin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:26,182 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'nitrofurantoin' (Index: 2977).
# 2024-11-16 20:24:26,184 - INFO - DATA EXTRACTION 4: Processing medication 'budesonide ' (Index: 3702).
# 2024-11-16 20:24:26,187 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:26,258 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'amoxicillin ' (Index: 2976).
# 2024-11-16 20:24:26,260 - INFO - DATA EXTRACTION 4: Processing medication 'Cefuroxime ' (Index: 3727).
# 2024-11-16 20:24:26,262 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:26,265 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AAspirin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:26,268 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Aspirin ' (Index: 3042).
# 2024-11-16 20:24:26,269 - INFO - DATA EXTRACTION 4: Processing medication 'sulfamethoxazole ' (Index: 3736).
# 2024-11-16 20:24:26,271 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:26,570 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AFexofenadine+hydrochloride+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:26,573 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Fexofenadine hydrochloride ' (Index: 3700).
# 2024-11-16 20:24:26,574 - INFO - DATA EXTRACTION 4: Processing medication 'Ortho Tri' (Index: 3762).
# 2024-11-16 20:24:26,576 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:27,014 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ANDA&limit=1 HTTP/11" 404 None
# 2024-11-16 20:24:27,016 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'NDA' (Index: 3701).
# 2024-11-16 20:24:27,017 - INFO - DATA EXTRACTION 4: Processing medication 'Sodium Chloride ' (Index: 3766).
# 2024-11-16 20:24:27,019 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:27,212 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Abudesonide+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:27,450 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'budesonide ' (Index: 3702).
# 2024-11-16 20:24:27,451 - INFO - DATA EXTRACTION 4: Processing medication 'Norinyl ' (Index: 3779).
# 2024-11-16 20:24:27,453 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:27,475 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Asulfamethoxazole+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:27,510 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ACefuroxime+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:27,513 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Cefuroxime ' (Index: 3727).
# 2024-11-16 20:24:27,514 - INFO - DATA EXTRACTION 4: Processing medication 'Naproxen ' (Index: 3784).
# 2024-11-16 20:24:27,517 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:27,522 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'sulfamethoxazole ' (Index: 3736).
# 2024-11-16 20:24:27,524 - INFO - DATA EXTRACTION 4: Processing medication 'Levothyroxine Sodium ' (Index: 3805).
# 2024-11-16 20:24:27,526 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:27,823 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AOrtho+Tri&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:27,825 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Ortho Tri' (Index: 3762).
# 2024-11-16 20:24:27,826 - INFO - DATA EXTRACTION 4: Processing medication 'Vitamin B' (Index: 3809).
# 2024-11-16 20:24:27,828 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:28,131 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ASodium+Chloride+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:28,133 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Sodium Chloride ' (Index: 3766).
# 2024-11-16 20:24:28,134 - INFO - DATA EXTRACTION 4: Processing medication '24 HR Metformin hydrochloride 500 MG Extended Release Oral Tablet' (Index: 3815).
# 2024-11-16 20:24:28,136 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:28,487 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ANorinyl+&limit=1 HTTP/11" 404 None
# 2024-11-16 20:24:28,490 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Norinyl ' (Index: 3779).
# 2024-11-16 20:24:28,491 - INFO - DATA EXTRACTION 4: Processing medication 'aspirin ' (Index: 3864).
# 2024-11-16 20:24:28,492 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:28,601 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ALevothyroxine+Sodium+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:28,604 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Levothyroxine Sodium ' (Index: 3805).
# 2024-11-16 20:24:28,606 - INFO - DATA EXTRACTION 4: Processing medication 'simvastatin ' (Index: 3865).
# 2024-11-16 20:24:28,608 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:28,731 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ANaproxen+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:28,842 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Naproxen ' (Index: 3784).
# 2024-11-16 20:24:28,843 - INFO - DATA EXTRACTION 4: Processing medication 'hydrochlorothiazide ' (Index: 3866).
# 2024-11-16 20:24:28,846 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:29,064 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AVitamin+B&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:29,220 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Vitamin B' (Index: 3809).
# 2024-11-16 20:24:29,222 - INFO - DATA EXTRACTION 4: Processing medication 'prasugrel ' (Index: 3867).
# 2024-11-16 20:24:29,225 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:29,270 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A24+HR+Metformin+hydrochloride+500+MG+Extended+Release+Oral+Tablet&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:29,276 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '24 HR Metformin hydrochloride 500 MG Extended Release Oral Tablet' (Index: 3815).
# 2024-11-16 20:24:29,277 - INFO - DATA EXTRACTION 4: Processing medication 'Furosemide ' (Index: 3880).
# 2024-11-16 20:24:29,280 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:29,474 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Aaspirin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:29,477 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'aspirin ' (Index: 3864).
# 2024-11-16 20:24:29,479 - INFO - DATA EXTRACTION 4: Processing medication 'diphenhydrAMINE Hydrochloride ' (Index: 3947).
# 2024-11-16 20:24:29,483 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:29,739 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Asimvastatin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:29,812 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Ahydrochlorothiazide+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:29,993 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'simvastatin ' (Index: 3865).
# 2024-11-16 20:24:29,994 - INFO - DATA EXTRACTION 4: Processing medication 'Hydrocortisone ' (Index: 4000).
# 2024-11-16 20:24:29,996 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:30,015 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'hydrochlorothiazide ' (Index: 3866).
# 2024-11-16 20:24:30,016 - INFO - DATA EXTRACTION 4: Processing medication '24 HR metoprolol succinate 50 MG Extended Release Oral Tablet' (Index: 4003).
# 2024-11-16 20:24:30,018 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:30,221 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AFurosemide+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:30,377 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Furosemide ' (Index: 3880).
# 2024-11-16 20:24:30,380 - INFO - DATA EXTRACTION 4: Processing medication 'atorvastatin ' (Index: 4004).
# 2024-11-16 20:24:30,382 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:30,383 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Aprasugrel+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:30,389 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'prasugrel ' (Index: 3867).
# 2024-11-16 20:24:30,390 - INFO - DATA EXTRACTION 4: Processing medication 'cephalexin ' (Index: 4010).
# 2024-11-16 20:24:30,392 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:30,416 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AdiphenhydrAMINE+Hydrochloride+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:30,419 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'diphenhydrAMINE Hydrochloride ' (Index: 3947).
# 2024-11-16 20:24:30,420 - INFO - DATA EXTRACTION 4: Processing medication 'tramadol hydrochloride ' (Index: 4024).
# 2024-11-16 20:24:30,423 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:30,992 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AHydrocortisone+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:30,997 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Hydrocortisone ' (Index: 4000).
# 2024-11-16 20:24:30,998 - INFO - DATA EXTRACTION 4: Processing medication '12 HR Hydrocodone Bitartrate 10 MG Extended Release Oral Capsule' (Index: 4025).
# 2024-11-16 20:24:31,000 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:31,353 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Aatorvastatin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:31,401 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Acephalexin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:31,402 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Atramadol+hydrochloride+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:31,407 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'tramadol hydrochloride ' (Index: 4024).
# 2024-11-16 20:24:31,408 - INFO - DATA EXTRACTION 4: Processing medication 'NuvaRing ' (Index: 4037).
# 2024-11-16 20:24:31,409 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:31,425 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A24+HR+metoprolol+succinate+50+MG+Extended+Release+Oral+Tablet&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:31,428 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '24 HR metoprolol succinate 50 MG Extended Release Oral Tablet' (Index: 4003).
# 2024-11-16 20:24:31,429 - INFO - DATA EXTRACTION 4: Processing medication 'Trinessa ' (Index: 4948).
# 2024-11-16 20:24:31,432 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:31,495 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'cephalexin ' (Index: 4010).
# 2024-11-16 20:24:31,496 - INFO - DATA EXTRACTION 4: Processing medication 'carvedilol ' (Index: 5139).
# 2024-11-16 20:24:31,498 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:31,560 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'atorvastatin ' (Index: 4004).
# 2024-11-16 20:24:31,561 - INFO - DATA EXTRACTION 4: Processing medication 'losartan potassium ' (Index: 5140).
# 2024-11-16 20:24:31,563 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:32,043 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A12+HR+Hydrocodone+Bitartrate+10+MG+Extended+Release+Oral+Capsule&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:32,046 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '12 HR Hydrocodone Bitartrate 10 MG Extended Release Oral Capsule' (Index: 4025).
# 2024-11-16 20:24:32,047 - INFO - DATA EXTRACTION 4: Processing medication 'sacubitril ' (Index: 5202).
# 2024-11-16 20:24:32,048 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:32,343 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ATrinessa+&limit=1 HTTP/11" 404 None
# 2024-11-16 20:24:32,345 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Trinessa ' (Index: 4948).
# 2024-11-16 20:24:32,346 - INFO - DATA EXTRACTION 4: Processing medication 'nebivolol ' (Index: 5337).
# 2024-11-16 20:24:32,348 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:32,419 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Acarvedilol+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:32,556 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ANuvaRing+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:32,561 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'NuvaRing ' (Index: 4037).
# 2024-11-16 20:24:32,562 - INFO - DATA EXTRACTION 4: Processing medication 'pravastatin sodium ' (Index: 5338).
# 2024-11-16 20:24:32,564 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:32,756 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Alosartan+potassium+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:32,761 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'losartan potassium ' (Index: 5140).
# 2024-11-16 20:24:32,764 - INFO - DATA EXTRACTION 4: Processing medication 'ciprofloxacin ' (Index: 5472).
# 2024-11-16 20:24:32,767 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:32,843 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'carvedilol ' (Index: 5139).
# 2024-11-16 20:24:32,844 - INFO - DATA EXTRACTION 4: Processing medication 'Camila ' (Index: 5475).
# 2024-11-16 20:24:32,846 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:33,143 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Asacubitril+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:33,198 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'sacubitril ' (Index: 5202).
# 2024-11-16 20:24:33,199 - INFO - DATA EXTRACTION 4: Processing medication 'cobicistat ' (Index: 5487).
# 2024-11-16 20:24:33,201 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:33,480 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Anebivolol+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:33,483 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'nebivolol ' (Index: 5337).
# 2024-11-16 20:24:33,485 - INFO - DATA EXTRACTION 4: Processing medication '168 HR Ethinyl Estradiol 0.00146 MG/HR / norelgestromin 0.00625 MG/HR Transdermal System' (Index: 5529).
# 2024-11-16 20:24:33,487 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:33,532 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Apravastatin+sodium+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:33,534 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'pravastatin sodium ' (Index: 5338).
# 2024-11-16 20:24:33,535 - INFO - DATA EXTRACTION 4: Processing medication 'Levora ' (Index: 5530).
# 2024-11-16 20:24:33,537 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:33,713 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Aciprofloxacin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:33,719 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'ciprofloxacin ' (Index: 5472).
# 2024-11-16 20:24:33,720 - INFO - DATA EXTRACTION 4: Processing medication 'Alteplase ' (Index: 5748).
# 2024-11-16 20:24:33,723 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:33,934 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ACamila+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:33,940 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Camila ' (Index: 5475).
# 2024-11-16 20:24:33,942 - INFO - DATA EXTRACTION 4: Processing medication 'FLUoxetine ' (Index: 5820).
# 2024-11-16 20:24:33,946 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:34,111 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Acobicistat+&limit=1 HTTP/11" 404 None
# 2024-11-16 20:24:34,119 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'cobicistat ' (Index: 5487).
# 2024-11-16 20:24:34,123 - INFO - DATA EXTRACTION 4: Processing medication 'buprenorphine ' (Index: 5843).
# 2024-11-16 20:24:34,130 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:34,426 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A168+HR+Ethinyl+Estradiol+0.00146+MG%2FHR+%2F+norelgestromin+0.00625+MG%2FHR+Transdermal+System&limit=1 HTTP/11" 500 243
# 2024-11-16 20:24:34,431 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '168 HR Ethinyl Estradiol 0.00146 MG/HR / norelgestromin 0.00625 MG/HR Transdermal System' (Index: 5529).
# 2024-11-16 20:24:34,435 - INFO - DATA EXTRACTION 4: Processing medication 'metoprolol tartrate ' (Index: 6860).
# 2024-11-16 20:24:34,444 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:34,454 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3ALevora+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:34,653 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AAlteplase+&limit=1 HTTP/11" 404 None
# 2024-11-16 20:24:34,655 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Alteplase ' (Index: 5748).
# 2024-11-16 20:24:34,657 - INFO - DATA EXTRACTION 4: Processing medication '24 HR Donepezil hydrochloride 10 MG / Memantine hydrochloride 28 MG Extended Release Oral Capsule' (Index: 7234).
# 2024-11-16 20:24:34,660 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:34,665 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Levora ' (Index: 5530).
# 2024-11-16 20:24:34,666 - INFO - DATA EXTRACTION 4: Processing medication 'Estrostep Fe ' (Index: 7269).
# 2024-11-16 20:24:34,669 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:35,043 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AFLUoxetine+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:35,221 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Abuprenorphine+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:35,253 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'FLUoxetine ' (Index: 5820).
# 2024-11-16 20:24:35,255 - INFO - DATA EXTRACTION 4: Processing medication 'Astemizole ' (Index: 7777).
# 2024-11-16 20:24:35,258 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:35,290 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'buprenorphine ' (Index: 5843).
# 2024-11-16 20:24:35,292 - INFO - DATA EXTRACTION 4: Processing medication 'doxycycline hyclate ' (Index: 7778).
# 2024-11-16 20:24:35,295 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:35,565 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Ametoprolol+tartrate+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:35,611 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3A24+HR+Donepezil+hydrochloride+10+MG+%2F+Memantine+hydrochloride+28+MG+Extended+Release+Oral+Capsule&limit=1 HTTP/11" 500 282
# 2024-11-16 20:24:35,613 - INFO - DATA EXTRACTION 4.1: Completed processing for medication '24 HR Donepezil hydrochloride 10 MG / Memantine hydrochloride 28 MG Extended Release Oral Capsule' (Index: 7234).
# 2024-11-16 20:24:35,614 - INFO - DATA EXTRACTION 4: Processing medication 'Azithromycin ' (Index: 7779).
# 2024-11-16 20:24:35,616 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:35,635 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'metoprolol tartrate ' (Index: 6860).
# 2024-11-16 20:24:35,636 - INFO - DATA EXTRACTION 4: Processing medication 'fosfomycin ' (Index: 7798).
# 2024-11-16 20:24:35,639 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:35,832 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AEstrostep+Fe+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:35,836 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Estrostep Fe ' (Index: 7269).
# 2024-11-16 20:24:35,837 - INFO - DATA EXTRACTION 4: Processing medication 'labetalol hydrochloride ' (Index: 8694).
# 2024-11-16 20:24:35,839 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:36,179 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AAstemizole+&limit=1 HTTP/11" 404 None
# 2024-11-16 20:24:36,182 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Astemizole ' (Index: 7777).
# 2024-11-16 20:24:36,183 - INFO - DATA EXTRACTION 4: Processing medication 'atenolol ' (Index: 8948).
# 2024-11-16 20:24:36,185 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:36,317 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Adoxycycline+hyclate+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:36,389 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'doxycycline hyclate ' (Index: 7778).
# 2024-11-16 20:24:36,390 - INFO - DATA EXTRACTION 4: Processing medication 'clonazePAM ' (Index: 9033).
# 2024-11-16 20:24:36,392 - DEBUG - Starting new HTTPS connection (1): api.fda.gov:443
# 2024-11-16 20:24:36,562 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AAzithromycin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:36,574 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Afosfomycin+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:36,577 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'fosfomycin ' (Index: 7798).
# 2024-11-16 20:24:36,797 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'Azithromycin ' (Index: 7779).
# 2024-11-16 20:24:36,800 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Alabetalol+hydrochloride+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:36,804 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'labetalol hydrochloride ' (Index: 8694).
# 2024-11-16 20:24:37,372 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3Aatenolol+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:37,408 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'atenolol ' (Index: 8948).
# 2024-11-16 20:24:37,572 - DEBUG - https://api.fda.gov:443 "GET /drug/label.json?search=openfda.brand_name%3AclonazePAM+&limit=1 HTTP/11" 200 None
# 2024-11-16 20:24:37,623 - INFO - DATA EXTRACTION 4.1: Completed processing for medication 'clonazePAM ' (Index: 9033).
# 2024-11-16 20:24:37,625 - INFO - DATA EXTRACTION 6: Completed parallel processing for all medications.
# 2024-11-16 20:24:37,627 - INFO - DATA LOADING: Saving the final DataFrame with 'EXTRACTED_MED_NAME' to CSV.
# 2024-11-16 20:24:37,631 - INFO - ETL Process Complete: Data processing and saving to CSV completed successfully.
# Data processing complete.

# %% [markdown]
# Task 9 - Setting up the PostgreSQL settings/configurations, to execute the DDLS

# %%
import pandas as pd
import sqlite3
from sqlalchemy import create_engine
import logging

# Load data from CSV files
logging.info("Loading CSV files...")
file_paths = {
    "patients": "/mnt/data/patient_infromation_dimension.csv",
    "claims": "/mnt/data/claim_dimension.csv",
    "medications": "/mnt/data/medication_dimension.csv",
    "encounters": "/mnt/data/events_encounters.csv",
    "diagnostic_reports": "/mnt/data/events_diagnostic_report.csv",
    "conditions": "/mnt/data/events_conditions.csv",
    "eob": "/mnt/data/eob_dimension.csv"
}
dfs = {name: pd.read_csv(path) for name, path in file_paths.items()}

# Establish SQLite connection
sqlite_db = 'health_datawarehouse.db'
conn = sqlite3.connect(sqlite_db)
cursor = conn.cursor()

# Establish SQLAlchemy engine
engine = create_engine(f'sqlite:///{sqlite_db}')

# Create new normalized tables and fact table (Adjust the fact table to business KPIs)
create_tables_sql = """
CREATE TABLE IF NOT EXISTS patients (
    PATIENT_ID VARCHAR(255) PRIMARY KEY,
    FIRST_NAME VARCHAR(255),
    LAST_NAME VARCHAR(255),
    GENDER VARCHAR(50),
    BIRTH_DATE DATE,
    AGE INT,
    CITY VARCHAR(100),
    POSTAL_CODE INT,
    COUNTRY VARCHAR(100),
    MSISDN VARCHAR(50)
);

CREATE TABLE IF NOT EXISTS claims (
    CLAIM_ID VARCHAR(255) PRIMARY KEY,
    PATIENT_ID VARCHAR(255),
    STATUS VARCHAR(50),
    BILLABLE_PERIOD_START TIMESTAMP,
    BILLABLE_PERIOD_END TIMESTAMP,
    COST DECIMAL,
    CURRENCY VARCHAR(50),
    INSURANCE VARCHAR(50),
    PRESCRIPTION_ID VARCHAR(255),
    FOREIGN KEY (PATIENT_ID) REFERENCES patients(PATIENT_ID)
);

CREATE TABLE IF NOT EXISTS medications (
    MEDICATION_ID VARCHAR(255) PRIMARY KEY,
    MEDICATION_NAME VARCHAR(255),
    COST DECIMAL,
    PRESCRIBER VARCHAR(255),
    REASON VARCHAR(255),
    PATIENT_ID VARCHAR(255),
    FOREIGN KEY (PATIENT_ID) REFERENCES patients(PATIENT_ID)
);

CREATE TABLE IF NOT EXISTS encounters (
    EVENT_ID VARCHAR(255) PRIMARY KEY,
    PATIENT_ID VARCHAR(255),
    EVENT_TYPE VARCHAR(255),
    COST DECIMAL,
    LOCATION TEXT,
    START_DATETIME TIMESTAMP,
    END_DATETIME TIMESTAMP,
    FOREIGN KEY (PATIENT_ID) REFERENCES patients(PATIENT_ID)
);

CREATE TABLE IF NOT EXISTS diagnostic_reports (
    REPORT_ID VARCHAR(255) PRIMARY KEY,
    PATIENT_ID VARCHAR(255),
    REPORT_TYPE VARCHAR(255),
    REPORT_DATE TIMESTAMP,
    FOREIGN KEY (PATIENT_ID) REFERENCES patients(PATIENT_ID)
);

CREATE TABLE IF NOT EXISTS conditions (
    CONDITION_ID VARCHAR(255) PRIMARY KEY,
    PATIENT_ID VARCHAR(255),
    CONDITION_NAME VARCHAR(255),
    DIAGNOSIS_DATE TIMESTAMP,
    FOREIGN KEY (PATIENT_ID) REFERENCES patients(PATIENT_ID)
);

CREATE TABLE IF NOT EXISTS fact_patient_metrics (
    METRIC_ID INTEGER PRIMARY KEY AUTOINCREMENT,
    PATIENT_ID VARCHAR(255),
    TOTAL_CLAIM_COST DECIMAL,
    TOTAL_MEDICATION_COST DECIMAL,
    TOTAL_ENCOUNTER_COST DECIMAL,
    TOTAL_CLAIM_COUNT INT,
    TOTAL_ENCOUNTER_COUNT INT,
    LAST_ENCOUNTER_DATE TIMESTAMP,
    AVERAGE_CLAIM_COST DECIMAL,
    AVERAGE_ENCOUNTER_COST DECIMAL,
    FOREIGN KEY (PATIENT_ID) REFERENCES patients(PATIENT_ID)
);
"""
cursor.executescript(create_tables_sql)
conn.commit()

# Prepare data for fact table
logging.info("Creating the fact table from joined data...")

# Perform joins between the tables
fact_table_data = pd.merge(dfs['patients'], dfs['claims'], how='left', on='PATIENT_ID')
fact_table_data = pd.merge(fact_table_data, dfs['medications'], how='left', on='PATIENT_ID')
fact_table_data = pd.merge(fact_table_data, dfs['encounters'], how='left', on='PATIENT_ID')
fact_table_data = pd.merge(fact_table_data, dfs['diagnostic_reports'], how='left', on='PATIENT_ID')
fact_table_data = pd.merge(fact_table_data, dfs['conditions'], how='left', on='PATIENT_ID')

# Calculate business metrics for the fact table
fact_table_data['TOTAL_CLAIM_COST'] = fact_table_data.groupby('PATIENT_ID')['COST_x'].transform('sum')
fact_table_data['TOTAL_MEDICATION_COST'] = fact_table_data.groupby('PATIENT_ID')['COST_y'].transform('sum')
fact_table_data['TOTAL_ENCOUNTER_COST'] = fact_table_data.groupby('PATIENT_ID')['COST'].transform('sum')
fact_table_data['TOTAL_CLAIM_COUNT'] = fact_table_data.groupby('PATIENT_ID')['CLAIM_ID'].transform('count')
fact_table_data['TOTAL_ENCOUNTER_COUNT'] = fact_table_data.groupby('PATIENT_ID')['EVENT_ID'].transform('count')
fact_table_data['LAST_ENCOUNTER_DATE'] = fact_table_data.groupby('PATIENT_ID')['START_DATETIME'].transform('max')
fact_table_data['AVERAGE_CLAIM_COST'] = fact_table_data['TOTAL_CLAIM_COST'] / fact_table_data['TOTAL_CLAIM_COUNT']
fact_table_data['AVERAGE_ENCOUNTER_COST'] = fact_table_data['TOTAL_ENCOUNTER_COST'] / fact_table_data['TOTAL_ENCOUNTER_COUNT']

# Insert data into the fact table
logging.info("Inserting data into fact_patient_metrics table...")
fact_table_data_to_insert = fact_table_data[['PATIENT_ID', 'TOTAL_CLAIM_COST', 'TOTAL_MEDICATION_COST', 'TOTAL_ENCOUNTER_COST',
                                            'TOTAL_CLAIM_COUNT', 'TOTAL_ENCOUNTER_COUNT', 'LAST_ENCOUNTER_DATE',
                                            'AVERAGE_CLAIM_COST', 'AVERAGE_ENCOUNTER_COST']]
fact_table_data_to_insert.to_sql('fact_patient_metrics', engine, if_exists='append', index=False)

# Close connections
logging.info("Closing database connections...")
cursor.close()
conn.close()
logging.info("Database connections closed successfully.")
# Out:
# INFO:root:DATA LOADING: Starting process to load and create tables.
# INFO:root:Dropping existing tables if they exist...
# INFO:root:Creating tables...
# INFO:root:Loading CSV files...
# INFO:root:Inserting data into tables...
# INFO:root:Inserting data into patient_hist table...
# /tmp/ipykernel_9141/70842474.py:196: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   patient_hist_data['CHANGE_DATE'] = pd.to_datetime('now')  # Add the current timestamp for change date
# /tmp/ipykernel_9141/70842474.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   patient_hist_data['CHANGE_DATE'] = pd.to_datetime('now')  # Add the current timestamp for change date
# INFO:root:Populating the fact_patient_metrics table...
